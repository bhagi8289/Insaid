# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagi8289/Insaid/blob/master/capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading https://files.pythonhosted.org/packages/40/f5/55dd794bb70a9b73510454ac3fb57c27450d70eaf5811f4fb618b80bcace/mysql_connector_python-8.0.16-cp36-cp36m-manylinux1_x86_64.whl (13.0MB)
#      |████████████████████████████████| 13.0MB 27kB/s
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from mysql-connector-python) (3.7.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.0.0->mysql-connector-python) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.0.0->mysql-connector-python) (41.0.1)
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-8.0.16

# %%
# !pip install mysql-connector-python
import pandas as pd
from IPython.display import display
from IPython.core.display import HTML
pd.options.mode.use_inf_as_na = True
pd.options.display.max_columns = None
pd.options.display.max_rows = None

import mysql.connector
from mysql.connector import Error
#from google.colab import drive
#drive.mount('/content/gdrive')
# Out:
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.6/dist-packages (8.0.16)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from mysql-connector-python) (3.7.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.0.0->mysql-connector-python) (41.0.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.0.0->mysql-connector-python) (1.12.0)

# %%
try:
    connection = mysql.connector.connect(host='capstone1.insaid.co',
                             database='Capstone1',
                             user='student',
                             password='student')
    if connection.is_connected():
       db_Info = connection.get_server_info()
       print("Connected to MySQL database... MySQL Server version on ",db_Info)

       cursor = connection.cursor()
       cursor.execute("select database()")
       record = cursor.fetchone()
       print ("Your connected to - ", record)
       #sql_select_Query = "select * from gender_age_train"
       sql_select_Query = "select * from gender_age_train"
       cursor = connection.cursor()
       cursor.execute(sql_select_Query)
       records = cursor.fetchall()
       print(type(records))

       print("Total number of rows in python_developers is - ", cursor.rowcount)
       print ("Printing each row's column values")
       for i in range(5):
        print("Gender = ", records[i][1])
        print("Age = ", records[i][2])
        print("AgeGroup  = ", records[i][3])
       cursor.close()
      
       sql = "select * from events_data"      
       df_events_data =  pd.read_sql(sql, connection)
       df_events_data.info()
       #df_events_data.to_csv("/content/gdrive//My Drive/capstone/df_events_data2.csv",index = None, header=True) 
        
       sql = "select * from gender_age_train"      
       df_gender_age_train =  pd.read_sql(sql, connection)
       df_gender_age_train.info()
       #df_gender_age_train.to_csv("/content/gdrive//My Drive/capstone/df_gender_age_train2.csv",index = None, header=True) 
      
       sql = "select * from phone_brand_device_model"      
       df_phone_brand_device_model =  pd.read_sql(sql, connection)
       df_phone_brand_device_model.info()
       #df_phone_brand_device_model.to_csv("/content/gdrive//My Drive/capstone/df_phone_brand_device_model2.csv",index = None, header=True)  
        
except Error as e :
    print ("Error while connecting to MySQL", e)
finally:
        #closing database connection.
    if(connection.is_connected()):
          connection.close()
          print("MySQL connection is closed")
# Out:
# Connected to MySQL database... MySQL Server version on  5.7.25-0ubuntu0.18.04.2
# Your connected to -  ('Capstone1',)
# <class 'list'>
# Total number of rows in python_developers is -  74645
# Printing each row's column values
# Gender =  M
# Age =  35
# AgeGroup  =  M32-38
# Gender =  M
# Age =  35
# AgeGroup  =  M32-38
# Gender =  M
# Age =  35
# AgeGroup  =  M32-38
# Gender =  M
# Age =  30
# AgeGroup  =  M29-31
# Gender =  M
# Age =  30
# AgeGroup  =  M29-31
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3252950 entries, 0 to 3252949
# Data columns (total 7 columns):
# event_id     int64
# device_id    int64
# timestamp    datetime64[ns]
# longitude    float64
# latitude     float64
# city         object
# state        object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 173.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74645 entries, 0 to 74644
# Data columns (total 4 columns):
# device_id    74645 non-null int64
# gender       74645 non-null object
# age          74645 non-null int64
# group        74645 non-null object
# dtypes: int64(2), object(2)
# memory usage: 2.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87726 entries, 0 to 87725
# Data columns (total 3 columns):
# device_id       87726 non-null int64
# phone_brand     87726 non-null object
# device_model    87726 non-null object
# dtypes: int64(1), object(2)
# memory usage: 2.0+ MB
# MySQL connection is closed

# %%
df_gender_age_train.info()
df_events_data.info()
df_phone_brand_device_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74645 entries, 0 to 74644
# Data columns (total 4 columns):
# device_id    74645 non-null int64
# gender       74645 non-null object
# age          74645 non-null int64
# group        74645 non-null object
# dtypes: int64(2), object(2)
# memory usage: 2.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3252950 entries, 0 to 3252949
# Data columns (total 7 columns):
# event_id     int64
# device_id    int64
# timestamp    datetime64[ns]
# longitude    float64
# latitude     float64
# city         object
# state        object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 173.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87726 entries, 0 to 87725
# Data columns (total 3 columns):
# device_id       87726 non-null int64
# phone_brand     87726 non-null object
# device_model    87726 non-null object
# dtypes: int64(1), object(2)
# memory usage: 2.0+ MB

# %%
df_gender_age_train.describe()
# Out:
#           device_id           age
# count  7.464500e+04  74645.000000
# mean  -7.491354e+14     31.410342
# std    5.327150e+18      9.868735
# min   -9.223067e+18      1.000000
# 25%   -4.617367e+18     25.000000
# 50%   -1.841362e+16     29.000000
# 75%    4.636656e+18     36.000000
# max    9.222849e+18     96.000000

# %%
df_events_data.describe()
# Out:
#            event_id     device_id     longitude      latitude
# count  3.252950e+06  3.252950e+06  3.252950e+06  3.252950e+06
# mean   1.626476e+06 -8.157164e+16  7.814869e+01  2.168594e+01
# std    9.390459e+05  5.347161e+18  4.326754e+00  5.793877e+00
# min    1.000000e+00 -9.223067e+18  0.000000e+00  0.000000e+00
# 25%    8.132382e+05 -4.727609e+18  7.583498e+01  1.780134e+01
# 50%    1.626476e+06 -1.248416e+17  7.726814e+01  2.216185e+01
# 75%    2.439713e+06  4.561184e+18  8.031916e+01  2.868276e+01
# max    3.252950e+06  9.221843e+18  9.545946e+01  4.187190e+01

# %%
df_phone_brand_device_model.describe()
# Out:
#           device_id
# count  8.772600e+04
# mean  -5.212557e+15
# std    5.330157e+18
# min   -9.223322e+18
# 25%   -4.623331e+18
# 50%   -3.109802e+16
# 75%    4.635194e+18
# max    9.222849e+18

# %%
df_gender_age_train.head()
# Out:
#              device_id gender  age   group
# 0 -8076087639492063270      M   35  M32-38
# 1 -2897161552818060146      M   35  M32-38
# 2 -8260683887967679142      M   35  M32-38
# 3 -4938849341048082022      M   30  M29-31
# 4   245133531816851882      M   30  M29-31

# %%
df_events_data.head()
# Out:
#    event_id            device_id           timestamp  longitude  latitude  \
# 0         1 -8163950559213451232 2016-05-01 00:55:25  77.266052  28.68161
# 1      7104 -8163950559213451232 2016-05-02 09:37:02  77.266052  28.68161
# 2     29661 -8163950559213451232 2016-05-04 00:56:04  77.266052  28.68161
# 3     33133 -8163950559213451232 2016-05-06 05:01:15  77.266052  28.68161
# 4     38980 -8163950559213451232 2016-05-06 09:55:04  77.266052  28.68161
#
#     city  state
# 0  Delhi  Delhi
# 1  Delhi  Delhi
# 2  Delhi  Delhi
# 3  Delhi  Delhi
# 4  Delhi  Delhi

# %%
df_phone_brand_device_model.head()
# Out:
#              device_id phone_brand device_model
# 0  1877775838486905855        vivo          Y13
# 1 -3766087376657242966          小米         V183
# 2 -6238937574958215831        OPPO          R7s
# 3  8973197758510677470          三星        A368t
# 4 -2015528097870762664          小米      红米Note2

# %%
#Brand Name	Brand English Mapping
brand_mapping = {
	'华为':'Huawei',
	'小米':'Xiaomi',
	'三星':'Samsung',
	'vivo':'vivo',
	'OPPO':'OPPO',
	'魅族':'Meizu',
	'酷派':'Coolpad',
  '奇酷':'Qi Cool',
	'乐视':'LeEco',
	'联想 ':'Lenovo',
    
	'HTC':'HTC'
}

brand_mapping = {
"Coolpad":"Coolpad",
"E人E本":"E person E this book",
"E派":"E pie",
"HTC":"HTC",
"Huawei":"Huawei",
"LG":"LG",
"LOGO":"LOGO",
"LeEco":"LeEco",
"Lenovo":"Lenovo",
"Lovme":"Lovme",
"MIL":"MIL",
"Meizu":"Meizu",
"OPPO":"OPPO",
"PPTV":"PPTV",
"Qi Cool":"Qi Cool",
"SUGAR":"SUGAR",
"Samsung":"Samsung",
"TCL":"TCL",
"Xiaomi":"Xiaomi",
"ZUK":"ZUK",
"vivo":"Vivo",
"一加":"One plus",
"世纪星":"Century Star",
"中国移动":"China Mobile",
"丰米":"Fengmi",
"乡米":"Township",
"亿通":"Yitong",
"优米":"Youmi",
"优语":"优语",
"优购":"Premium",
"先锋":"Pioneer",
"凯利通":"Kelly",
"努比亚":"Nubia",
"华硕":"ASUS",
"台电":"Taipower",
"唯比":"Only",
"唯米":"Wei Mi",
"基伍":"Kivu",
"夏新":"Amoi",
"大Q":"Big Q",
"大可乐":"Coca-Cola",
"大显":"Daxian",
"天语":"Tianyu",
"奥克斯":"Oaks",
"宝捷讯":"Bao Jiexun",
"富可视":"InFocus",
"小杨树":"Small poplar",
"尼比鲁":"Nibiru",
"帷幄":"Weiwo",
"广信":"Guangxin",
"康佳":"Konka",
"德赛":"Desai",
"恒宇丰":"Heng Yufeng",
"惠普":"HP",
"摩乐":"Moor",
"摩托罗拉":"Motorola",
"斐讯":"Fiji",
"昂达":"Onda",
"易派":"Easy to send",
"普耐尔":"Pnell",
"智镁":"Zhimag",
"本为":"This is",
"朵唯":"Duo Wei",
"果米":"Fruit rice",
"梦米":"Dream rice",
"欧乐迪":"Oraldi",
"欧博信":"Ou Boxin",
"欧奇":"Ouqi",
"欧新":"Ou Xin",
"欧比":"Obi",
"欧沃":"Ovo",
"沃普丰":"Warpfonte",
"波导":"Bird",
"海信":"Hisense",
"海尔":"Haier",
"爱派尔":"Ai Pai",
"瑞米":"Remi",
"瑞高":"Regal",
"白米":"White rice",
"百加":"Bai Jia",
"百立丰":"Bai Lifeng",
"神舟":"Shenzhou",
"米奇":"Mickey",
"米歌":"Mi Ge",
"糖葫芦":"Candied fruit",
"糯米":"Glutinous rice",
"纽曼":"Newman",
"维图":"Vital",
"美图":"Beautiful picture",
"聆韵":"Listening rhyme",
"至尊宝":"Supreme treasure",
"艾优尼":"Aiuni",
"蓝魔":"Blue Devil",
"虾米":"Shrimp",
"西米":"Simi",
"西门子":"Siemens",
"语信":"Language letter",
"诺亚信":"Noahs letter",
"诺基亚":"Nokia",
"谷歌":"Google",
"贝尔丰":"Bellevue",
"赛博宇华":"Saibo Yuhua",
"邦华":"Banghua",
"酷比":"Cool ratio",
"酷比魔方":"Cool than Rubiks Cube",
"酷珀":"Cooler",
"金星数码":"Venus Digital",
"锤子":"Hammer",
"长虹":"Changhong",
"青橙":"Green",
"青葱":"Shallots",
"飞利浦":"Philips",
"飞秒":"Femtosecond",
"首云":"First cloud",
"鲜米":"Fresh rice",
"黑米":"Black rice",
"三星":"Samsung",
"乐视":"LeTV",
"优语":"Yuyu",
"华为":"Huawei",
"奇酷":"Qi Cool",
"小米":"Millet",
"帷幄":"Weiwo",
"联想":"Lenovo",
"酷派":"Cool",
"魅族":"Meizu"
}


for x in brand_mapping:
  print(brand_mapping[x])
  
for x in brand_mapping.keys():
  print(x)

for x in brand_mapping.values():
  print(x)

for x,y in brand_mapping.items():
  print(x,y)

print("length of dictionary is: ",len(brand_mapping))
# Out:
# Coolpad
# E person E this book
# E pie
# HTC
# Huawei
# LG
# LOGO
# LeEco
# Lenovo
# Lovme
# MIL
# Meizu
# OPPO
# PPTV
# Qi Cool
# SUGAR
# Samsung
# TCL
# Xiaomi
# ZUK
# Vivo
# One plus
# Century Star
# China Mobile
# Fengmi
# Township
# Yitong
# Youmi
# Yuyu
# Premium
# Pioneer
# Kelly
# Nubia
# ASUS
# Taipower
# Only
# Wei Mi
# Kivu
# Amoi
# Big Q
# Coca-Cola
# Daxian
# Tianyu
# Oaks
# Bao Jiexun
# InFocus
# Small poplar
# Nibiru
# Weiwo
# Guangxin
# Konka
# Desai
# Heng Yufeng
# HP
# Moor
# Motorola
# Fiji
# Onda
# Easy to send
# Pnell
# Zhimag
# This is
# Duo Wei
# Fruit rice
# Dream rice
# Oraldi
# Ou Boxin
# Ouqi
# Ou Xin
# Obi
# Ovo
# Warpfonte
# Bird
# Hisense
# Haier
# Ai Pai
# Remi
# Regal
# White rice
# Bai Jia
# Bai Lifeng
# Shenzhou
# Mickey
# Mi Ge
# Candied fruit
# Glutinous rice
# Newman
# Vital
# Beautiful picture
# Listening rhyme
# Supreme treasure
# Aiuni
# Blue Devil
# Shrimp
# Simi
# Siemens
# Language letter
# Noahs letter
# Nokia
# Google
# Bellevue
# Saibo Yuhua
# Banghua
# Cool ratio
# Cool than Rubiks Cube
# Cooler
# Venus Digital
# Hammer
# Changhong
# Green
# Shallots
# Philips
# Femtosecond
# First cloud
# Fresh rice
# Black rice
# Samsung
# LeTV
# Huawei
# Qi Cool
# Millet
# Lenovo
# Cool
# Meizu
# Coolpad
# E人E本
# E派
# HTC
# Huawei
# LG
# LOGO
# LeEco
# Lenovo
# Lovme
# MIL
# Meizu
# OPPO
# PPTV
# Qi Cool
# SUGAR
# Samsung
# TCL
# Xiaomi
# ZUK
# vivo
# 一加
# 世纪星
# 中国移动
# 丰米
# 乡米
# 亿通
# 优米
# 优语
# 优购
# 先锋
# 凯利通
# 努比亚
# 华硕
# 台电
# 唯比
# 唯米
# 基伍
# 夏新
# 大Q
# 大可乐
# 大显
# 天语
# 奥克斯
# 宝捷讯
# 富可视
# 小杨树
# 尼比鲁
# 帷幄
# 广信
# 康佳
# 德赛
# 恒宇丰
# 惠普
# 摩乐
# 摩托罗拉
# 斐讯
# 昂达
# 易派
# 普耐尔
# 智镁
# 本为
# 朵唯
# 果米
# 梦米
# 欧乐迪
# 欧博信
# 欧奇
# 欧新
# 欧比
# 欧沃
# 沃普丰
# 波导
# 海信
# 海尔
# 爱派尔
# 瑞米
# 瑞高
# 白米
# 百加
# 百立丰
# 神舟
# 米奇
# 米歌
# 糖葫芦
# 糯米
# 纽曼
# 维图
# 美图
# 聆韵
# 至尊宝
# 艾优尼
# 蓝魔
# 虾米
# 西米
# 西门子
# 语信
# 诺亚信
# 诺基亚
# 谷歌
# 贝尔丰
# 赛博宇华
# 邦华
# 酷比
# 酷比魔方
# 酷珀
# 金星数码
# 锤子
# 长虹
# 青橙
# 青葱
# 飞利浦
# 飞秒
# 首云
# 鲜米
# 黑米
# 三星
# 乐视
# 华为
# 奇酷
# 小米
# 联想
# 酷派
# 魅族
# Coolpad
# E person E this book
# E pie
# HTC
# Huawei
# LG
# LOGO
# LeEco
# Lenovo
# Lovme
# MIL
# Meizu
# OPPO
# PPTV
# Qi Cool
# SUGAR
# Samsung
# TCL
# Xiaomi
# ZUK
# Vivo
# One plus
# Century Star
# China Mobile
# Fengmi
# Township
# Yitong
# Youmi
# Yuyu
# Premium
# Pioneer
# Kelly
# Nubia
# ASUS
# Taipower
# Only
# Wei Mi
# Kivu
# Amoi
# Big Q
# Coca-Cola
# Daxian
# Tianyu
# Oaks
# Bao Jiexun
# InFocus
# Small poplar
# Nibiru
# Weiwo
# Guangxin
# Konka
# Desai
# Heng Yufeng
# HP
# Moor
# Motorola
# Fiji
# Onda
# Easy to send
# Pnell
# Zhimag
# This is
# Duo Wei
# Fruit rice
# Dream rice
# Oraldi
# Ou Boxin
# Ouqi
# Ou Xin
# Obi
# Ovo
# Warpfonte
# Bird
# Hisense
# Haier
# Ai Pai
# Remi
# Regal
# White rice
# Bai Jia
# Bai Lifeng
# Shenzhou
# Mickey
# Mi Ge
# Candied fruit
# Glutinous rice
# Newman
# Vital
# Beautiful picture
# Listening rhyme
# Supreme treasure
# Aiuni
# Blue Devil
# Shrimp
# Simi
# Siemens
# Language letter
# Noahs letter
# Nokia
# Google
# Bellevue
# Saibo Yuhua
# Banghua
# Cool ratio
# Cool than Rubiks Cube
# Cooler
# Venus Digital
# Hammer
# Changhong
# Green
# Shallots
# Philips
# Femtosecond
# First cloud
# Fresh rice
# Black rice
# Samsung
# LeTV
# Huawei
# Qi Cool
# Millet
# Lenovo
# Cool
# Meizu
# Coolpad Coolpad
# E人E本 E person E this book
# E派 E pie
# HTC HTC
# Huawei Huawei
# LG LG
# LOGO LOGO
# LeEco LeEco
# Lenovo Lenovo
# Lovme Lovme
# MIL MIL
# Meizu Meizu
# OPPO OPPO
# PPTV PPTV
# Qi Cool Qi Cool
# SUGAR SUGAR
# Samsung Samsung
# TCL TCL
# Xiaomi Xiaomi
# ZUK ZUK
# vivo Vivo
# 一加 One plus
# 世纪星 Century Star
# 中国移动 China Mobile
# 丰米 Fengmi
# 乡米 Township
# 亿通 Yitong
# 优米 Youmi
# 优语 Yuyu
# 优购 Premium
# 先锋 Pioneer
# 凯利通 Kelly
# 努比亚 Nubia
# 华硕 ASUS
# 台电 Taipower
# 唯比 Only
# 唯米 Wei Mi
# 基伍 Kivu
# 夏新 Amoi
# 大Q Big Q
# 大可乐 Coca-Cola
# 大显 Daxian
# 天语 Tianyu
# 奥克斯 Oaks
# 宝捷讯 Bao Jiexun
# 富可视 InFocus
# 小杨树 Small poplar
# 尼比鲁 Nibiru
# 帷幄 Weiwo
# 广信 Guangxin
# 康佳 Konka
# 德赛 Desai
# 恒宇丰 Heng Yufeng
# 惠普 HP
# 摩乐 Moor
# 摩托罗拉 Motorola
# 斐讯 Fiji
# 昂达 Onda
# 易派 Easy to send
# 普耐尔 Pnell
# 智镁 Zhimag
# 本为 This is
# 朵唯 Duo Wei
# 果米 Fruit rice
# 梦米 Dream rice
# 欧乐迪 Oraldi
# 欧博信 Ou Boxin
# 欧奇 Ouqi
# 欧新 Ou Xin
# 欧比 Obi
# 欧沃 Ovo
# 沃普丰 Warpfonte
# 波导 Bird
# 海信 Hisense
# 海尔 Haier
# 爱派尔 Ai Pai
# 瑞米 Remi
# 瑞高 Regal
# 白米 White rice
# 百加 Bai Jia
# 百立丰 Bai Lifeng
# 神舟 Shenzhou
# 米奇 Mickey
# 米歌 Mi Ge
# 糖葫芦 Candied fruit
# 糯米 Glutinous rice
# 纽曼 Newman
# 维图 Vital
# 美图 Beautiful picture
# 聆韵 Listening rhyme
# 至尊宝 Supreme treasure
# 艾优尼 Aiuni
# 蓝魔 Blue Devil
# 虾米 Shrimp
# 西米 Simi
# 西门子 Siemens
# 语信 Language letter
# 诺亚信 Noahs letter
# 诺基亚 Nokia
# 谷歌 Google
# 贝尔丰 Bellevue
# 赛博宇华 Saibo Yuhua
# 邦华 Banghua
# 酷比 Cool ratio
# 酷比魔方 Cool than Rubiks Cube
# 酷珀 Cooler
# 金星数码 Venus Digital
# 锤子 Hammer
# 长虹 Changhong
# 青橙 Green
# 青葱 Shallots
# 飞利浦 Philips
# 飞秒 Femtosecond
# 首云 First cloud
# 鲜米 Fresh rice
# 黑米 Black rice
# 三星 Samsung
# 乐视 LeTV
# 华为 Huawei
# 奇酷 Qi Cool
# 小米 Millet
# 联想 Lenovo
# 酷派 Cool
# 魅族 Meizu
# length of dictionary is:  124

# %%
print(brand_mapping.items())
print(brand_mapping.keys())
print(brand_mapping.values())
# Out:
# dict_items([('Coolpad', 'Coolpad'), ('E人E本', 'E person E this book'), ('E派', 'E pie'), ('HTC', 'HTC'), ('Huawei', 'Huawei'), ('LG', 'LG'), ('LOGO', 'LOGO'), ('LeEco', 'LeEco'), ('Lenovo', 'Lenovo'), ('Lovme', 'Lovme'), ('MIL', 'MIL'), ('Meizu', 'Meizu'), ('OPPO', 'OPPO'), ('PPTV', 'PPTV'), ('Qi Cool', 'Qi Cool'), ('SUGAR', 'SUGAR'), ('Samsung', 'Samsung'), ('TCL', 'TCL'), ('Xiaomi', 'Xiaomi'), ('ZUK', 'ZUK'), ('vivo', 'Vivo'), ('一加', 'One plus'), ('世纪星', 'Century Star'), ('中国移动', 'China Mobile'), ('丰米', 'Fengmi'), ('乡米', 'Township'), ('亿通', 'Yitong'), ('优米', 'Youmi'), ('优语', 'Yuyu'), ('优购', 'Premium'), ('先锋', 'Pioneer'), ('凯利通', 'Kelly'), ('努比亚', 'Nubia'), ('华硕', 'ASUS'), ('台电', 'Taipower'), ('唯比', 'Only'), ('唯米', 'Wei Mi'), ('基伍', 'Kivu'), ('夏新', 'Amoi'), ('大Q', 'Big Q'), ('大可乐', 'Coca-Cola'), ('大显', 'Daxian'), ('天语', 'Tianyu'), ('奥克斯', 'Oaks'), ('宝捷讯', 'Bao Jiexun'), ('富可视', 'InFocus'), ('小杨树', 'Small poplar'), ('尼比鲁', 'Nibiru'), ('帷幄', 'Weiwo'), ('广信', 'Guangxin'), ('康佳', 'Konka'), ('德赛', 'Desai'), ('恒宇丰', 'Heng Yufeng'), ('惠普', 'HP'), ('摩乐', 'Moor'), ('摩托罗拉', 'Motorola'), ('斐讯', 'Fiji'), ('昂达', 'Onda'), ('易派', 'Easy to send'), ('普耐尔', 'Pnell'), ('智镁', 'Zhimag'), ('本为', 'This is'), ('朵唯', 'Duo Wei'), ('果米', 'Fruit rice'), ('梦米', 'Dream rice'), ('欧乐迪', 'Oraldi'), ('欧博信', 'Ou Boxin'), ('欧奇', 'Ouqi'), ('欧新', 'Ou Xin'), ('欧比', 'Obi'), ('欧沃', 'Ovo'), ('沃普丰', 'Warpfonte'), ('波导', 'Bird'), ('海信', 'Hisense'), ('海尔', 'Haier'), ('爱派尔', 'Ai Pai'), ('瑞米', 'Remi'), ('瑞高', 'Regal'), ('白米', 'White rice'), ('百加', 'Bai Jia'), ('百立丰', 'Bai Lifeng'), ('神舟', 'Shenzhou'), ('米奇', 'Mickey'), ('米歌', 'Mi Ge'), ('糖葫芦', 'Candied fruit'), ('糯米', 'Glutinous rice'), ('纽曼', 'Newman'), ('维图', 'Vital'), ('美图', 'Beautiful picture'), ('聆韵', 'Listening rhyme'), ('至尊宝', 'Supreme treasure'), ('艾优尼', 'Aiuni'), ('蓝魔', 'Blue Devil'), ('虾米', 'Shrimp'), ('西米', 'Simi'), ('西门子', 'Siemens'), ('语信', 'Language letter'), ('诺亚信', 'Noahs letter'), ('诺基亚', 'Nokia'), ('谷歌', 'Google'), ('贝尔丰', 'Bellevue'), ('赛博宇华', 'Saibo Yuhua'), ('邦华', 'Banghua'), ('酷比', 'Cool ratio'), ('酷比魔方', 'Cool than Rubiks Cube'), ('酷珀', 'Cooler'), ('金星数码', 'Venus Digital'), ('锤子', 'Hammer'), ('长虹', 'Changhong'), ('青橙', 'Green'), ('青葱', 'Shallots'), ('飞利浦', 'Philips'), ('飞秒', 'Femtosecond'), ('首云', 'First cloud'), ('鲜米', 'Fresh rice'), ('黑米', 'Black rice'), ('三星', 'Samsung'), ('乐视', 'LeTV'), ('华为', 'Huawei'), ('奇酷', 'Qi Cool'), ('小米', 'Millet'), ('联想', 'Lenovo'), ('酷派', 'Cool'), ('魅族', 'Meizu')])
# dict_keys(['Coolpad', 'E人E本', 'E派', 'HTC', 'Huawei', 'LG', 'LOGO', 'LeEco', 'Lenovo', 'Lovme', 'MIL', 'Meizu', 'OPPO', 'PPTV', 'Qi Cool', 'SUGAR', 'Samsung', 'TCL', 'Xiaomi', 'ZUK', 'vivo', '一加', '世纪星', '中国移动', '丰米', '乡米', '亿通', '优米', '优语', '优购', '先锋', '凯利通', '努比亚', '华硕', '台电', '唯比', '唯米', '基伍', '夏新', '大Q', '大可乐', '大显', '天语', '奥克斯', '宝捷讯', '富可视', '小杨树', '尼比鲁', '帷幄', '广信', '康佳', '德赛', '恒宇丰', '惠普', '摩乐', '摩托罗拉', '斐讯', '昂达', '易派', '普耐尔', '智镁', '本为', '朵唯', '果米', '梦米', '欧乐迪', '欧博信', '欧奇', '欧新', '欧比', '欧沃', '沃普丰', '波导', '海信', '海尔', '爱派尔', '瑞米', '瑞高', '白米', '百加', '百立丰', '神舟', '米奇', '米歌', '糖葫芦', '糯米', '纽曼', '维图', '美图', '聆韵', '至尊宝', '艾优尼', '蓝魔', '虾米', '西米', '西门子', '语信', '诺亚信', '诺基亚', '谷歌', '贝尔丰', '赛博宇华', '邦华', '酷比', '酷比魔方', '酷珀', '金星数码', '锤子', '长虹', '青橙', '青葱', '飞利浦', '飞秒', '首云', '鲜米', '黑米', '三星', '乐视', '华为', '奇酷', '小米', '联想', '酷派', '魅族'])
# dict_values(['Coolpad', 'E person E this book', 'E pie', 'HTC', 'Huawei', 'LG', 'LOGO', 'LeEco', 'Lenovo', 'Lovme', 'MIL', 'Meizu', 'OPPO', 'PPTV', 'Qi Cool', 'SUGAR', 'Samsung', 'TCL', 'Xiaomi', 'ZUK', 'Vivo', 'One plus', 'Century Star', 'China Mobile', 'Fengmi', 'Township', 'Yitong', 'Youmi', 'Yuyu', 'Premium', 'Pioneer', 'Kelly', 'Nubia', 'ASUS', 'Taipower', 'Only', 'Wei Mi', 'Kivu', 'Amoi', 'Big Q', 'Coca-Cola', 'Daxian', 'Tianyu', 'Oaks', 'Bao Jiexun', 'InFocus', 'Small poplar', 'Nibiru', 'Weiwo', 'Guangxin', 'Konka', 'Desai', 'Heng Yufeng', 'HP', 'Moor', 'Motorola', 'Fiji', 'Onda', 'Easy to send', 'Pnell', 'Zhimag', 'This is', 'Duo Wei', 'Fruit rice', 'Dream rice', 'Oraldi', 'Ou Boxin', 'Ouqi', 'Ou Xin', 'Obi', 'Ovo', 'Warpfonte', 'Bird', 'Hisense', 'Haier', 'Ai Pai', 'Remi', 'Regal', 'White rice', 'Bai Jia', 'Bai Lifeng', 'Shenzhou', 'Mickey', 'Mi Ge', 'Candied fruit', 'Glutinous rice', 'Newman', 'Vital', 'Beautiful picture', 'Listening rhyme', 'Supreme treasure', 'Aiuni', 'Blue Devil', 'Shrimp', 'Simi', 'Siemens', 'Language letter', 'Noahs letter', 'Nokia', 'Google', 'Bellevue', 'Saibo Yuhua', 'Banghua', 'Cool ratio', 'Cool than Rubiks Cube', 'Cooler', 'Venus Digital', 'Hammer', 'Changhong', 'Green', 'Shallots', 'Philips', 'Femtosecond', 'First cloud', 'Fresh rice', 'Black rice', 'Samsung', 'LeTV', 'Huawei', 'Qi Cool', 'Millet', 'Lenovo', 'Cool', 'Meizu'])

# %%
df_phone_brand_device_model.head()

for x,y in brand_mapping.items():
  print(x,y)
  df_phone_brand_device_model.replace({x:y},regex=True,inplace=True)
# Out:
# Coolpad Coolpad
# E人E本 E person E this book
# E派 E pie
# HTC HTC
# Huawei Huawei
# LG LG
# LOGO LOGO
# LeEco LeEco
# Lenovo Lenovo
# Lovme Lovme
# MIL MIL
# Meizu Meizu
# OPPO OPPO
# PPTV PPTV
# Qi Cool Qi Cool
# SUGAR SUGAR
# Samsung Samsung
# TCL TCL
# Xiaomi Xiaomi
# ZUK ZUK
# vivo Vivo
# 一加 One plus
# 世纪星 Century Star
# 中国移动 China Mobile
# 丰米 Fengmi
# 乡米 Township
# 亿通 Yitong
# 优米 Youmi
# 优语 Yuyu
# 优购 Premium
# 先锋 Pioneer
# 凯利通 Kelly
# 努比亚 Nubia
# 华硕 ASUS
# 台电 Taipower
# 唯比 Only
# 唯米 Wei Mi
# 基伍 Kivu
# 夏新 Amoi
# 大Q Big Q
# 大可乐 Coca-Cola
# 大显 Daxian
# 天语 Tianyu
# 奥克斯 Oaks
# 宝捷讯 Bao Jiexun
# 富可视 InFocus
# 小杨树 Small poplar
# 尼比鲁 Nibiru
# 帷幄 Weiwo
# 广信 Guangxin
# 康佳 Konka
# 德赛 Desai
# 恒宇丰 Heng Yufeng
# 惠普 HP
# 摩乐 Moor
# 摩托罗拉 Motorola
# 斐讯 Fiji
# 昂达 Onda
# 易派 Easy to send
# 普耐尔 Pnell
# 智镁 Zhimag
# 本为 This is
# 朵唯 Duo Wei
# 果米 Fruit rice
# 梦米 Dream rice
# 欧乐迪 Oraldi
# 欧博信 Ou Boxin
# 欧奇 Ouqi
# 欧新 Ou Xin
# 欧比 Obi
# 欧沃 Ovo
# 沃普丰 Warpfonte
# 波导 Bird
# 海信 Hisense
# 海尔 Haier
# 爱派尔 Ai Pai
# 瑞米 Remi
# 瑞高 Regal
# 白米 White rice
# 百加 Bai Jia
# 百立丰 Bai Lifeng
# 神舟 Shenzhou
# 米奇 Mickey
# 米歌 Mi Ge
# 糖葫芦 Candied fruit
# 糯米 Glutinous rice
# 纽曼 Newman
# 维图 Vital
# 美图 Beautiful picture
# 聆韵 Listening rhyme
# 至尊宝 Supreme treasure
# 艾优尼 Aiuni
# 蓝魔 Blue Devil
# 虾米 Shrimp
# 西米 Simi
# 西门子 Siemens
# 语信 Language letter
# 诺亚信 Noahs letter
# 诺基亚 Nokia
# 谷歌 Google
# 贝尔丰 Bellevue
# 赛博宇华 Saibo Yuhua
# 邦华 Banghua
# 酷比 Cool ratio
# 酷比魔方 Cool than Rubiks Cube
# 酷珀 Cooler
# 金星数码 Venus Digital
# 锤子 Hammer
# 长虹 Changhong
# 青橙 Green
# 青葱 Shallots
# 飞利浦 Philips
# 飞秒 Femtosecond
# 首云 First cloud
# 鲜米 Fresh rice
# 黑米 Black rice
# 三星 Samsung
# 乐视 LeTV
# 华为 Huawei
# 奇酷 Qi Cool
# 小米 Millet
# 联想 Lenovo
# 酷派 Cool
# 魅族 Meizu

# %%
df_phone_brand_device_model.head()
# Out:
#              device_id phone_brand device_model
# 0  1877775838486905855        Vivo          Y13
# 1 -3766087376657242966      Millet         V183
# 2 -6238937574958215831        OPPO          R7s
# 3  8973197758510677470     Samsung        A368t
# 4 -2015528097870762664      Millet      红米Note2

# %%
#df_phone_brand_device_model

# %%
df_phone_brand_device_model.count()
# Out:
# device_id       87726
# phone_brand     87726
# device_model    87726
# dtype: int64

# %%
#Types of Phone Brands used by customers

from IPython.display import display

pd.options.display.max_columns = None
pd.options.display.max_rows = None
from IPython.core.display import HTML
display(HTML(df_phone_brand_device_model.groupby('phone_brand').count()[['device_model']].to_html()))
#df_phone_brand_device_model.groupby('phone_brand').count()[['device_model']]
#print(df_phone_brand_device_model.groupby('phone_brand').count().device_model.index)
#print(df_phone_brand_device_model.groupby('phone_brand').count().device_model.values)
#df_phone_brand_device_model.groupby('phone_brand').count().device_model
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>device_model</th>
#     </tr>
#     <tr>
#       <th>phone_brand</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ASUS</th>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>Ai Pai</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>Aiuni</th>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>Amoi</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>Bai Jia</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Bai Lifeng</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>Banghua</th>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>Bao Jiexun</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Beautiful picture</th>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>Bellevue</th>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>Big Q</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Bird</th>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>Black rice</th>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>Blue Devil</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Candied fruit</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Century Star</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Changhong</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>China Mobile</th>
#       <td>309</td>
#     </tr>
#     <tr>
#       <th>Coca-Cola</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>Cool</th>
#       <td>3979</td>
#     </tr>
#     <tr>
#       <th>Cool ratio</th>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>Cool ratio魔方</th>
#       <td>78</td>
#     </tr>
#     <tr>
#       <th>Cooler</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>Daxian</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Desai</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Dream rice</th>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>Duo Wei</th>
#       <td>253</td>
#     </tr>
#     <tr>
#       <th>E person E this book</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>E pie</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Easy to send</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Femtosecond</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Fengmi</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Fiji</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>First cloud</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Fresh rice</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Fruit rice</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>Glutinous rice</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>Google</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>Green</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>Guangxin</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>HP</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>HTC</th>
#       <td>1272</td>
#     </tr>
#     <tr>
#       <th>Haier</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>Hammer</th>
#       <td>257</td>
#     </tr>
#     <tr>
#       <th>Heng Yufeng</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Hisense</th>
#       <td>218</td>
#     </tr>
#     <tr>
#       <th>Huawei</th>
#       <td>15181</td>
#     </tr>
#     <tr>
#       <th>InFocus</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>Kelly</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Kivu</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Konka</th>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>LG</th>
#       <td>360</td>
#     </tr>
#     <tr>
#       <th>LOGO</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>Language letter</th>
#       <td>170</td>
#     </tr>
#     <tr>
#       <th>LeTV</th>
#       <td>841</td>
#     </tr>
#     <tr>
#       <th>Lenovo</th>
#       <td>982</td>
#     </tr>
#     <tr>
#       <th>Listening rhyme</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>Lovme</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>MIL</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Meizu</th>
#       <td>5531</td>
#     </tr>
#     <tr>
#       <th>Mi Ge</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>Mickey</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Millet</th>
#       <td>21645</td>
#     </tr>
#     <tr>
#       <th>Moor</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Motorola</th>
#       <td>106</td>
#     </tr>
#     <tr>
#       <th>Newman</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>Nibiru</th>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>Noahs letter</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Nokia</th>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>Nubia</th>
#       <td>540</td>
#     </tr>
#     <tr>
#       <th>OPPO</th>
#       <td>6717</td>
#     </tr>
#     <tr>
#       <th>Oaks</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Obi</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Onda</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>One plus</th>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>Only</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Oraldi</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Ou Boxin</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>Ou Xin</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Ouqi</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Ovo</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>PPTV</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Philips</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Pioneer</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>Pnell</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Premium</th>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>Qi Cool</th>
#       <td>174</td>
#     </tr>
#     <tr>
#       <th>Regal</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Remi</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>SUGAR</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Saibo Yuhua</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Samsung</th>
#       <td>19211</td>
#     </tr>
#     <tr>
#       <th>Shallots</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>Shenzhou</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Shrimp</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Siemens</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Simi</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Small poplar</th>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>Supreme treasure</th>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>TCL</th>
#       <td>280</td>
#     </tr>
#     <tr>
#       <th>Taipower</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>This is</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Tianyu</th>
#       <td>161</td>
#     </tr>
#     <tr>
#       <th>Township</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>Venus Digital</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Vital</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>Vivo</th>
#       <td>7596</td>
#     </tr>
#     <tr>
#       <th>Warpfonte</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Wei Mi</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Weiwo</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>White rice</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Yitong</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>Youmi</th>
#       <td>243</td>
#     </tr>
#     <tr>
#       <th>Yuyu</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>ZUK</th>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>Zhimag</th>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Week1 Tasks
# Check Null values
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100
df_events_data.isna().sum()
#df_events_data.notna()
check_device_id = df_events_data['device_id'] == 0
#check_device_id.head()
#type(check_device_id)
check_device_id.groupby(check_device_id.values).count()
# Out:
# False    3252495
# True         455
# Name: device_id, dtype: int64

# %%
df_gender_age_train.isna().sum()
check_device_id = df_gender_age_train['device_id'] == 0
check_device_id.groupby(check_device_id.values).count()
# Out:
# False    74645
# Name: device_id, dtype: int64

# %%
df_phone_brand_device_model.isna().sum()
check_device_id = df_phone_brand_device_model['device_id'] == 0
check_device_id.groupby(check_device_id.values).count()
# Out:
# False    87726
# Name: device_id, dtype: int64

# %%
df_events_data[df_events_data['device_id'] == 0]
# Out:
#          event_id  device_id           timestamp  longitude   latitude  \
# 29200      122554          0 2016-05-06 03:54:51  77.271446  28.743046
# 29205      123777          0 2016-05-05 06:50:31  77.271446  28.743046
# 29256      292240          0 2016-05-03 00:08:47  77.271446  28.743046
# 29258      292348          0 2016-05-04 00:47:35  77.271446  28.743046
# 29320      479644          0 2016-05-05 04:58:21  77.271446  28.743046
# 29403      694947          0 2016-05-01 01:02:43  77.271446  28.743046
# 29444      806153          0 2016-05-01 01:51:16  77.271446  28.743046
# 29523     1030333          0 2016-05-04 06:22:58  77.271446  28.743046
# 29534     1051838          0 2016-05-05 04:59:45  77.271446  28.743046
# 29546     1078043          0 2016-05-07 00:29:02  77.271446  28.743046
# 29631     1304010          0 2016-05-05 05:00:56  77.271446  28.743046
# 29653     1357418          0 2016-05-05 04:55:06  77.271446  28.743046
# 29697     1494048          0 2016-05-03 05:16:42  77.271446  28.743046
# 29708     1502519          0 2016-05-01 01:25:19  77.271446  28.743046
# 29793     1791030          0 2016-05-04 01:29:25  77.271446  28.743046
# 29811     1867282          0 2016-05-07 00:39:13  77.271446  28.743046
# 29864     1958444          0 2016-05-05 05:00:55  77.271446  28.743046
# 30020     2386138          0 2016-05-04 04:58:36  77.271446  28.743046
# 30037     2441358          0 2016-05-03 01:20:19  77.271446  28.743046
# 30072     2569303          0 2016-05-03 00:29:45  77.271446  28.743046
# 30287     3220355          0 2016-05-06 00:56:09  77.271446  28.743046
# 428008     131885          0 2016-05-07 12:42:02  77.304710  28.713657
# 428013     138697          0 2016-05-05 18:19:33  77.304710  28.713657
# 428064     312715          0 2016-05-07 16:28:02  77.304710  28.713657
# 428066     317854          0 2016-05-05 19:48:22  77.304710  28.713657
# 428090     377245          0 2016-05-07 13:10:02  77.304710  28.713657
# 428128     461689          0 2016-05-02 22:17:26  77.304710  28.713657
# 428193     643962          0 2016-05-03 20:42:27  77.304710  28.713657
# 428211     689637          0 2016-05-03 20:35:26  77.304710  28.713657
# 428252     800131          0 2016-05-07 19:00:03  77.304710  28.713657
# 428331    1018030          0 2016-05-05 17:21:32  77.304710  28.713657
# 428334    1024319          0 2016-05-02 22:19:26  77.304710  28.713657
# 428342    1054348          0 2016-05-02 22:52:48  77.304710  28.713657
# 428354    1098911          0 2016-05-04 19:54:34  77.304710  28.713657
# 428439    1348710          0 2016-05-05 19:57:33  77.304710  28.713657
# 428461    1410987          0 2016-05-04 21:53:34  77.304710  28.713657
# 428505    1525261          0 2016-05-04 19:51:34  77.304710  28.713657
# 428516    1535547          0 2016-05-02 23:46:26  77.304710  28.713657
# 428601    1783058          0 2016-05-05 19:38:33  77.304710  28.713657
# 428619    1839457          0 2016-05-02 22:15:37  77.304710  28.713657
# 428672    2000878          0 2016-05-07 15:27:02  77.304710  28.713657
# 428828    2413469          0 2016-05-07 20:19:03  77.304710  28.713657
# 428845    2460840          0 2016-05-05 19:37:33  77.304710  28.713657
# 428880    2557234          0 2016-05-02 15:02:05  77.304710  28.713657
# 429052    3104378          0 2016-05-07 15:26:02  77.304710  28.713657
# 429095    3211407          0 2016-05-04 20:08:34  77.304710  28.713657
# 505183     110185          0 2016-05-04 18:27:46  77.267487  28.760448
# 505189     114346          0 2016-05-01 20:37:07  77.267487  28.760448
# 505205     180328          0 2016-05-05 16:53:35  77.267487  28.760448
# 505326     503196          0 2016-05-05 15:32:36  77.267487  28.760448
# ...           ...        ...                 ...        ...        ...
# 3046068   1918920          0 2016-05-04 00:02:48  87.018669  23.756069
# 3046091   2256916          0 2016-05-05 06:55:03  87.018669  23.756069
# 3046093   2308269          0 2016-05-07 07:02:28  87.018669  23.756069
# 3046104   2424827          0 2016-05-05 11:00:15  87.018669  23.756069
# 3046126   2639644          0 2016-05-02 06:08:43  87.018669  23.756069
# 3046137   2775599          0 2016-05-06 09:56:56  87.018669  23.756069
# 3046140   2819629          0 2016-05-04 02:31:41  87.018669  23.756069
# 3051139    110259          0 2016-05-04 18:40:53  88.526978  23.020517
# 3051140    111792          0 2016-05-03 22:03:01  88.526978  23.020517
# 3051141    112264          0 2016-05-03 19:35:48  88.526978  23.020517
# 3051142    131389          0 2016-05-05 12:22:18  88.526978  23.020517
# 3051155    267013          0 2016-05-03 00:52:28  88.526978  23.020517
# 3051161    312139          0 2016-05-04 16:33:34  88.526978  23.020517
# 3051176    513593          0 2016-05-05 12:15:48  88.526978  23.020517
# 3051200    727968          0 2016-05-05 23:30:33  88.526978  23.020517
# 3051225   1019022          0 2016-05-03 18:03:23  88.526978  23.020517
# 3051232   1131518          0 2016-05-07 23:10:20  88.526978  23.020517
# 3051241   1261641          0 2016-05-05 19:31:48  88.526978  23.020517
# 3051244   1286442          0 2016-05-05 15:12:10  88.526978  23.020517
# 3051247   1297916          0 2016-05-01 22:08:19  88.526978  23.020517
# 3051261   1490729          0 2016-05-06 23:19:59  88.526978  23.020517
# 3051265   1517373          0 2016-05-01 00:18:22  88.526978  23.020517
# 3051270   1567320          0 2016-05-04 23:19:15  88.526978  23.020517
# 3051282   1691097          0 2016-05-05 23:07:02  88.526978  23.020517
# 3051291   1799672          0 2016-05-04 11:08:19  88.526978  23.020517
# 3051294   1857835          0 2016-05-05 16:13:44  88.526978  23.020517
# 3051315   2152930          0 2016-05-05 12:18:42  88.526978  23.020517
# 3051317   2181079          0 2016-05-05 10:30:11  88.526978  23.020517
# 3051321   2265733          0 2016-05-07 13:47:16  88.526978  23.020517
# 3051328   2416542          0 2016-05-05 21:06:40  88.526978  23.020517
# 3051350   2672296          0 2016-05-02 18:14:06  88.526978  23.020517
# 3051361   2788238          0 2016-05-05 20:37:12  88.526978  23.020517
# 3051364   2836508          0 2016-05-05 19:27:39  88.526978  23.020517
# 3051366   2850943          0 2016-05-04 10:25:46  88.526978  23.020517
# 3079656    133611          0 2016-05-04 14:13:05  73.017395  20.643639
# 3079657    135269          0 2016-05-06 15:03:50  73.017395  20.643639
# 3079661    174461          0 2016-05-07 10:59:41  73.017395  20.643639
# 3079691    418535          0 2016-05-07 06:30:32  73.017395  20.643639
# 3079703    567875          0 2016-05-07 04:07:53  73.017395  20.643639
# 3079715    679451          0 2016-05-01 14:15:02  73.017395  20.643639
# 3079747   1058460          0 2016-05-05 08:25:53  73.017395  20.643639
# 3079762   1217865          0 2016-05-03 04:12:18  73.017395  20.643639
# 3079785   1531885          0 2016-05-02 09:02:17  73.017395  20.643639
# 3079797   1693289          0 2016-05-01 18:31:50  73.017395  20.643639
# 3079806   1816707          0 2016-05-06 01:28:20  73.017395  20.643639
# 3079832   2256799          0 2016-05-04 06:38:11  73.017395  20.643639
# 3079843   2395690          0 2016-05-06 11:02:52  73.017395  20.643639
# 3079865   2612498          0 2016-05-03 11:08:26  73.017395  20.643639
# 3079876   2742735          0 2016-05-07 10:01:03  73.017395  20.643639
# 3079881   2818954          0 2016-05-02 01:12:05  73.017395  20.643639
#
#              city       state
# 29200       Delhi       Delhi
# 29205       Delhi       Delhi
# 29256       Delhi       Delhi
# 29258       Delhi       Delhi
# 29320       Delhi       Delhi
# 29403       Delhi       Delhi
# 29444       Delhi       Delhi
# 29523       Delhi       Delhi
# 29534       Delhi       Delhi
# 29546       Delhi       Delhi
# 29631       Delhi       Delhi
# 29653       Delhi       Delhi
# 29697       Delhi       Delhi
# 29708       Delhi       Delhi
# 29793       Delhi       Delhi
# 29811       Delhi       Delhi
# 29864       Delhi       Delhi
# 30020       Delhi       Delhi
# 30037       Delhi       Delhi
# 30072       Delhi       Delhi
# 30287       Delhi       Delhi
# 428008      Delhi       Delhi
# 428013      Delhi       Delhi
# 428064      Delhi       Delhi
# 428066      Delhi       Delhi
# 428090      Delhi       Delhi
# 428128      Delhi       Delhi
# 428193      Delhi       Delhi
# 428211      Delhi       Delhi
# 428252      Delhi       Delhi
# 428331      Delhi       Delhi
# 428334      Delhi       Delhi
# 428342      Delhi       Delhi
# 428354      Delhi       Delhi
# 428439      Delhi       Delhi
# 428461      Delhi       Delhi
# 428505      Delhi       Delhi
# 428516      Delhi       Delhi
# 428601      Delhi       Delhi
# 428619      Delhi       Delhi
# 428672      Delhi       Delhi
# 428828      Delhi       Delhi
# 428845      Delhi       Delhi
# 428880      Delhi       Delhi
# 429052      Delhi       Delhi
# 429095      Delhi       Delhi
# 505183      Delhi       Delhi
# 505189      Delhi       Delhi
# 505205      Delhi       Delhi
# 505326      Delhi       Delhi
# ...           ...         ...
# 3046068   Asansol  WestBengal
# 3046091   Asansol  WestBengal
# 3046093   Asansol  WestBengal
# 3046104   Asansol  WestBengal
# 3046126   Asansol  WestBengal
# 3046137   Asansol  WestBengal
# 3046140   Asansol  WestBengal
# 3051139  Gayespur  WestBengal
# 3051140  Gayespur  WestBengal
# 3051141  Gayespur  WestBengal
# 3051142  Gayespur  WestBengal
# 3051155  Gayespur  WestBengal
# 3051161  Gayespur  WestBengal
# 3051176  Gayespur  WestBengal
# 3051200  Gayespur  WestBengal
# 3051225  Gayespur  WestBengal
# 3051232  Gayespur  WestBengal
# 3051241  Gayespur  WestBengal
# 3051244  Gayespur  WestBengal
# 3051247  Gayespur  WestBengal
# 3051261  Gayespur  WestBengal
# 3051265  Gayespur  WestBengal
# 3051270  Gayespur  WestBengal
# 3051282  Gayespur  WestBengal
# 3051291  Gayespur  WestBengal
# 3051294  Gayespur  WestBengal
# 3051315  Gayespur  WestBengal
# 3051317  Gayespur  WestBengal
# 3051321  Gayespur  WestBengal
# 3051328  Gayespur  WestBengal
# 3051350  Gayespur  WestBengal
# 3051361  Gayespur  WestBengal
# 3051364  Gayespur  WestBengal
# 3051366  Gayespur  WestBengal
# 3079656    Valsad     Gujarat
# 3079657    Valsad     Gujarat
# 3079661    Valsad     Gujarat
# 3079691    Valsad     Gujarat
# 3079703    Valsad     Gujarat
# 3079715    Valsad     Gujarat
# 3079747    Valsad     Gujarat
# 3079762    Valsad     Gujarat
# 3079785    Valsad     Gujarat
# 3079797    Valsad     Gujarat
# 3079806    Valsad     Gujarat
# 3079832    Valsad     Gujarat
# 3079843    Valsad     Gujarat
# 3079865    Valsad     Gujarat
# 3079876    Valsad     Gujarat
# 3079881    Valsad     Gujarat
#
# [455 rows x 7 columns]
